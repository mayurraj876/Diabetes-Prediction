# %%
import numpy as np   
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#models
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from keras.models import Sequential
from keras.layers import Dense
#Evaluation
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix, classification_report,plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# # Data processing

# %%
data = pd.read_csv("diabetes.csv")
attributes = data.drop("Outcome",axis=1).columns
for attribute in attributes:
    plt.figure()
    sns.violinplot(x="Outcome", y=attribute, data=data, palette="muted", split=True)

# %%
#replacing missing value with nan value
data[["Glucose",  "BloodPressure","SkinThickness","Insulin","BMI"]]=data[["Glucose",  "BloodPressure","SkinThickness","Insulin","BMI"]].replace(0,np.nan)

#loop for replacing outlier of all attribute with Nan value 
for attribute in attributes:
    q1 = data[attribute].quantile(0.25)
    q3 = data[attribute].quantile(0.75)
    iqr = q3 - q1
    fence_low = q1 - 1.5 * iqr
    fence_high = q3 + 1.5 * iqr
    data.loc[(data[attribute] < fence_low) | (data[attribute] > fence_high),attribute]=np.nan

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               764 non-null    float64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             719 non-null    float64
#  3   SkinThickness             538 non-null    float64
#  4   Insulin                   370 non-null    float64
#  5   BMI                       749 non-null    float64
#  6   DiabetesPedigreeFunction  739 non-null    float64
#  7   Age                       759 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB
# None

# %%
# calculation of median for each attribute for both possible 
def median_target(attribute):   
        temp = data[data[attribute].notnull()]# assigning non null value to temp 
        temp = temp[[attribute, 'Outcome']].groupby(['Outcome'])[[attribute]].median().reset_index() #calculate mean for a attribute with either 0 or 1 outcome 
        mean_op_0=temp[attribute][0]
        mean_op_1=temp[attribute][1]
        data.loc[(data['Outcome'] == 0 ) & (data[attribute].isnull()), attribute] = mean_op_0 #assigning mean to null values 
        data.loc[(data['Outcome'] == 1 ) & (data[attribute].isnull()), attribute] = mean_op_1
#calling meadian_target for each attribute
for attribute in attributes:
        median_target(attribute) 
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB
# None

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))
fig.tight_layout(pad=3.0)
ax[0,0].set_title('Glucose')
ax[0,0].hist(data.Glucose[data.Outcome==1]);
ax[0,1].set_title('Pregnancies')
ax[0,1].hist(data.Pregnancies[data.Outcome==1]);
ax[1,0].set_title('Age')
ax[1,0].hist(data.Age[data.Outcome==1]);
ax[1,1].set_title('Blood Pressure')
ax[1,1].hist(data.BloodPressure[data.Outcome==1]);
ax[2,0].set_title('Skin Thickness')
ax[2,0].hist(data.SkinThickness[data.Outcome==1]);
ax[2,1].set_title('Insulin')
ax[2,1].hist(data.Insulin[data.Outcome==1]);
ax[3,0].set_title('BMI')
ax[3,0].hist(data.BMI[data.Outcome==1]);
ax[3,1].set_title('Diabetes Pedigree Function')
ax[3,1].hist(data.DiabetesPedigreeFunction[data.Outcome==1]);

# %%
for attribute in attributes:
    plt.figure()    
    sns.violinplot(x="Outcome", y=attribute, data=data, palette="muted", split=True)

# %%
# standardization of dataset
def z_score(df):
    """Function for apply z score standardization
       Input: dataframe to be standardized
       output :standardized dataframe 
    """
    df_std = df.copy()
    for column in df_std.columns:
        df_std[column] = (df_std[column] - df_std[column].mean()) / df_std[column].std()     
    return df_std
data_std=z_score(data)

# %%
# It shows the correlation(positive,neagative) between different columns(only integer value columns) 
corr_matrix = data_std.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,annot=True,linewidth=0.5,fmt=".2f",cmap="RdYlBu")

# %% [markdown]
# ###### Distribution of data set

# %%
y = data["Outcome"]
X=data_std.drop("Outcome",axis=1)
X_train,X_test,y_train,y_test =  train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Models

# %%
list_of_algo=[SVC(),AdaBoostClassifier(), 
              RandomForestClassifier(),
              LogisticRegression(),KNeighborsClassifier()]
name_of_algo=["SVM","AdaBoostClassifier", 
              "RandomForestClassifier",
              "LogisticRegression","KNeighborsClassifier"]
for i,algorithm in enumerate(list_of_algo):
    model=algorithm
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    model_score=cross_val_score(model,X,y,cv=15)
    print("*"*120)
    print('Accuracy of {} : {} '.format(name_of_algo[i],(model_score.mean()*100)))
    print('Precision of {} : {} '.format(name_of_algo[i],(model_score.mean()*100)))
    plot_confusion_matrix(model, X_test, y_test,values_format="d")
    plt.title(name_of_algo[i])
    plt.show()
# Out:
# ************************************************************************************************************************
# Accuracy of SVM : 86.3222724987431
# Precision of SVM : 86.3222724987431
# ************************************************************************************************************************
# Accuracy of AdaBoostClassifier : 87.49120160884868
# Precision of AdaBoostClassifier : 87.49120160884868
# ************************************************************************************************************************
# Accuracy of RandomForestClassifier : 89.58773252890902
# Precision of RandomForestClassifier : 89.58773252890902
# ************************************************************************************************************************
# Accuracy of LogisticRegression : 79.16038210155858
# Precision of LogisticRegression : 79.16038210155858
# ************************************************************************************************************************
# Accuracy of KNeighborsClassifier : 84.50980392156865
# Precision of KNeighborsClassifier : 84.50980392156865

# %%
from sklearn.model_selection import GridSearchCV
print(RandomForestClassifier())
n_estimators = [100, 200, 250, 300, 350]
max_depth = [1, 3, 4, 5, 8, 10]
min_samples_split = [10, 15, 20, 25, 30, 100]
min_samples_leaf = [1, 2, 4, 5, 7] 
max_features = ['auto', 'sqrt']
bootstrap = [True, False]
rfr=RandomForestClassifier()
hyperF = dict(n_estimators = n_estimators, max_depth = max_depth,
              max_features = max_features,  min_samples_split = min_samples_split, 
              min_samples_leaf = min_samples_leaf,bootstrap = bootstrap)

gridF = GridSearchCV(rfr, hyperF,scoring='accuracy', cv = 5, verbose = 1, 
                      n_jobs = -1)
bestF = gridF.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   36.9s finished

# %%
print(bestF.best_params_)
forestOpt = RandomForestClassifier(bootstrap=False, max_depth = 5,max_features="sqrt", n_estimators = 200, min_samples_split = 15, min_samples_leaf = 2)
                                   
modelOpt = forestOpt.fit(X_train, y_train)
y_pred = modelOpt.predict(X_test)
print(modelOpt.score(X_test,y_test))
# Out:
# {'n_estimators': 350, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'max_depth': 4, 'bootstrap': True}
# 0.8896103896103896

# %%
##Build an model(Neural model )
model = Sequential()
model.add(Dense(8, input_dim=8, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=200, batch_size=10)
_, nn_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 0s 754us/step - loss: 0.6030 - accuracy: 0.6629
# Epoch 2/200
# 62/62 [==============================] - 0s 657us/step - loss: 0.4897 - accuracy: 0.7573
# Epoch 3/200
# 62/62 [==============================] - 0s 708us/step - loss: 0.4539 - accuracy: 0.7980
# Epoch 4/200
# 62/62 [==============================] - 0s 661us/step - loss: 0.4296 - accuracy: 0.8062
# Epoch 5/200
# 62/62 [==============================] - 0s 629us/step - loss: 0.4078 - accuracy: 0.8274
# Epoch 6/200
# 62/62 [==============================] - 0s 713us/step - loss: 0.4056 - accuracy: 0.8208
# Epoch 7/200
# 62/62 [==============================] - 0s 658us/step - loss: 0.3744 - accuracy: 0.8322
# Epoch 8/200
# 62/62 [==============================] - 0s 658us/step - loss: 0.3670 - accuracy: 0.8469
# Epoch 9/200
# 62/62 [==============================] - 0s 724us/step - loss: 0.3425 - accuracy: 0.8534
# Epoch 10/200
# 62/62 [==============================] - 0s 656us/step - loss: 0.3375 - accuracy: 0.8534
# Epoch 11/200
# 62/62 [==============================] - 0s 746us/step - loss: 0.3214 - accuracy: 0.8713
# Epoch 12/200
# 62/62 [==============================] - 0s 706us/step - loss: 0.3139 - accuracy: 0.8746
# Epoch 13/200
# 62/62 [==============================] - 0s 720us/step - loss: 0.3023 - accuracy: 0.8746
# Epoch 14/200
# 62/62 [==============================] - 0s 636us/step - loss: 0.2965 - accuracy: 0.8779
# Epoch 15/200
# 62/62 [==============================] - 0s 795us/step - loss: 0.2905 - accuracy: 0.8795
# Epoch 16/200
# 62/62 [==============================] - 0s 769us/step - loss: 0.2847 - accuracy: 0.8827
# Epoch 17/200
# 62/62 [==============================] - 0s 662us/step - loss: 0.2762 - accuracy: 0.8893
# Epoch 18/200
# 62/62 [==============================] - 0s 745us/step - loss: 0.2691 - accuracy: 0.8925
# Epoch 19/200
# 62/62 [==============================] - 0s 652us/step - loss: 0.2617 - accuracy: 0.8909
# Epoch 20/200
# 62/62 [==============================] - 0s 689us/step - loss: 0.2603 - accuracy: 0.8974
# Epoch 21/200
# 62/62 [==============================] - 0s 756us/step - loss: 0.2583 - accuracy: 0.8958
# Epoch 22/200
# 62/62 [==============================] - 0s 740us/step - loss: 0.2532 - accuracy: 0.8925
# Epoch 23/200
# 62/62 [==============================] - 0s 751us/step - loss: 0.2453 - accuracy: 0.9072
# Epoch 24/200
# 62/62 [==============================] - 0s 742us/step - loss: 0.2361 - accuracy: 0.9072
# Epoch 25/200
# 62/62 [==============================] - 0s 710us/step - loss: 0.2327 - accuracy: 0.9039
# Epoch 26/200
# 62/62 [==============================] - 0s 756us/step - loss: 0.2335 - accuracy: 0.9072
# Epoch 27/200
# 62/62 [==============================] - 0s 666us/step - loss: 0.2282 - accuracy: 0.9039
# Epoch 28/200
# 62/62 [==============================] - 0s 729us/step - loss: 0.2229 - accuracy: 0.9121
# Epoch 29/200
# 62/62 [==============================] - 0s 885us/step - loss: 0.2271 - accuracy: 0.9023
# Epoch 30/200
# 62/62 [==============================] - 0s 965us/step - loss: 0.2166 - accuracy: 0.9104
# Epoch 31/200
# 62/62 [==============================] - 0s 885us/step - loss: 0.2130 - accuracy: 0.9007
# Epoch 32/200
# 62/62 [==============================] - 0s 981us/step - loss: 0.2060 - accuracy: 0.9121
# Epoch 33/200
# 62/62 [==============================] - 0s 858us/step - loss: 0.2099 - accuracy: 0.9088
# Epoch 34/200
# 62/62 [==============================] - 0s 949us/step - loss: 0.2023 - accuracy: 0.9186
# Epoch 35/200
# 62/62 [==============================] - 0s 869us/step - loss: 0.2057 - accuracy: 0.9202
# Epoch 36/200
# 62/62 [==============================] - 0s 772us/step - loss: 0.1980 - accuracy: 0.9218
# Epoch 37/200
# 62/62 [==============================] - 0s 724us/step - loss: 0.1959 - accuracy: 0.9169
# Epoch 38/200
# 62/62 [==============================] - 0s 708us/step - loss: 0.1926 - accuracy: 0.9283
# Epoch 39/200
# 62/62 [==============================] - 0s 788us/step - loss: 0.1918 - accuracy: 0.9267
# Epoch 40/200
# 62/62 [==============================] - 0s 660us/step - loss: 0.1823 - accuracy: 0.9300
# Epoch 41/200
# 62/62 [==============================] - 0s 660us/step - loss: 0.1860 - accuracy: 0.9218
# Epoch 42/200
# 62/62 [==============================] - 0s 660us/step - loss: 0.1850 - accuracy: 0.9251
# Epoch 43/200
# 62/62 [==============================] - 0s 694us/step - loss: 0.1724 - accuracy: 0.9365
# Epoch 44/200
# 62/62 [==============================] - 0s 641us/step - loss: 0.1715 - accuracy: 0.9251
# Epoch 45/200
# 62/62 [==============================] - 0s 722us/step - loss: 0.1700 - accuracy: 0.9332
# Epoch 46/200
# 62/62 [==============================] - 0s 647us/step - loss: 0.1625 - accuracy: 0.9381
# Epoch 47/200
# 62/62 [==============================] - 0s 660us/step - loss: 0.1756 - accuracy: 0.9365
# Epoch 48/200
# 62/62 [==============================] - 0s 639us/step - loss: 0.1654 - accuracy: 0.9381
# Epoch 49/200
# 62/62 [==============================] - 0s 804us/step - loss: 0.1575 - accuracy: 0.9446
# Epoch 50/200
# 62/62 [==============================] - 0s 710us/step - loss: 0.1559 - accuracy: 0.9430
# Epoch 51/200
# 62/62 [==============================] - 0s 645us/step - loss: 0.1523 - accuracy: 0.9381
# Epoch 52/200
# 62/62 [==============================] - 0s 698us/step - loss: 0.1517 - accuracy: 0.9414
# Epoch 53/200
# 62/62 [==============================] - 0s 676us/step - loss: 0.1480 - accuracy: 0.9463
# Epoch 54/200
# 62/62 [==============================] - 0s 687us/step - loss: 0.1527 - accuracy: 0.9397
# Epoch 55/200
# 62/62 [==============================] - 0s 617us/step - loss: 0.1488 - accuracy: 0.9414
# Epoch 56/200
# 62/62 [==============================] - 0s 618us/step - loss: 0.1457 - accuracy: 0.9511
# Epoch 57/200
# 62/62 [==============================] - 0s 643us/step - loss: 0.1458 - accuracy: 0.9495
# Epoch 58/200
# 62/62 [==============================] - 0s 657us/step - loss: 0.1407 - accuracy: 0.9511
# Epoch 59/200
# 62/62 [==============================] - 0s 629us/step - loss: 0.1275 - accuracy: 0.9495
# Epoch 60/200
# 62/62 [==============================] - 0s 630us/step - loss: 0.1247 - accuracy: 0.9577
# Epoch 61/200
# 62/62 [==============================] - 0s 663us/step - loss: 0.1296 - accuracy: 0.9593
# Epoch 62/200
# 62/62 [==============================] - 0s 634us/step - loss: 0.1214 - accuracy: 0.9609
# Epoch 63/200
# 62/62 [==============================] - 0s 602us/step - loss: 0.1246 - accuracy: 0.9479
# Epoch 64/200
# 62/62 [==============================] - 0s 614us/step - loss: 0.1301 - accuracy: 0.9495
# Epoch 65/200
# 62/62 [==============================] - 0s 634us/step - loss: 0.1204 - accuracy: 0.9528
# Epoch 66/200
# 62/62 [==============================] - 0s 664us/step - loss: 0.1155 - accuracy: 0.9544
# Epoch 67/200
# 62/62 [==============================] - 0s 651us/step - loss: 0.1306 - accuracy: 0.9528
# Epoch 68/200
# 62/62 [==============================] - 0s 631us/step - loss: 0.1122 - accuracy: 0.9625
# Epoch 69/200
# 62/62 [==============================] - 0s 634us/step - loss: 0.1062 - accuracy: 0.9609
# Epoch 70/200
# 62/62 [==============================] - 0s 624us/step - loss: 0.1098 - accuracy: 0.9593
# Epoch 71/200
# 62/62 [==============================] - 0s 597us/step - loss: 0.1021 - accuracy: 0.9625
# Epoch 72/200
# 62/62 [==============================] - 0s 609us/step - loss: 0.1028 - accuracy: 0.9625
# Epoch 73/200
# 62/62 [==============================] - 0s 686us/step - loss: 0.0991 - accuracy: 0.9674
# Epoch 74/200
# 62/62 [==============================] - 0s 848us/step - loss: 0.0945 - accuracy: 0.9609
# Epoch 75/200
# 62/62 [==============================] - 0s 736us/step - loss: 0.0935 - accuracy: 0.9658
# Epoch 76/200
# 62/62 [==============================] - 0s 739us/step - loss: 0.1086 - accuracy: 0.9593
# Epoch 77/200
# 62/62 [==============================] - 0s 719us/step - loss: 0.0986 - accuracy: 0.9658
# Epoch 78/200
# 62/62 [==============================] - 0s 704us/step - loss: 0.0924 - accuracy: 0.9691
# Epoch 79/200
# 62/62 [==============================] - 0s 726us/step - loss: 0.0974 - accuracy: 0.9625
# Epoch 80/200
# 62/62 [==============================] - 0s 704us/step - loss: 0.0976 - accuracy: 0.9691
# Epoch 81/200
# 62/62 [==============================] - 0s 750us/step - loss: 0.0882 - accuracy: 0.9707
# Epoch 82/200
# 62/62 [==============================] - 0s 710us/step - loss: 0.0848 - accuracy: 0.9707
# Epoch 83/200
# 62/62 [==============================] - 0s 732us/step - loss: 0.0895 - accuracy: 0.9674
# Epoch 84/200
# 62/62 [==============================] - 0s 674us/step - loss: 0.0875 - accuracy: 0.9625
# Epoch 85/200
# 62/62 [==============================] - 0s 631us/step - loss: 0.0939 - accuracy: 0.9609
# Epoch 86/200
# 62/62 [==============================] - 0s 723us/step - loss: 0.0878 - accuracy: 0.9707
# Epoch 87/200
# 62/62 [==============================] - 0s 668us/step - loss: 0.0801 - accuracy: 0.9739
# Epoch 88/200
# 62/62 [==============================] - 0s 666us/step - loss: 0.0723 - accuracy: 0.9756
# Epoch 89/200
# 62/62 [==============================] - 0s 701us/step - loss: 0.0881 - accuracy: 0.9674
# Epoch 90/200
# 62/62 [==============================] - 0s 711us/step - loss: 0.0738 - accuracy: 0.9756
# Epoch 91/200
# 62/62 [==============================] - 0s 718us/step - loss: 0.0790 - accuracy: 0.9707
# Epoch 92/200
# 62/62 [==============================] - 0s 935us/step - loss: 0.0746 - accuracy: 0.9707
# Epoch 93/200
# 62/62 [==============================] - 0s 979us/step - loss: 0.0936 - accuracy: 0.9691
# Epoch 94/200
# 62/62 [==============================] - 0s 949us/step - loss: 0.0700 - accuracy: 0.9756
# Epoch 95/200
# 62/62 [==============================] - 0s 817us/step - loss: 0.0834 - accuracy: 0.9691
# Epoch 96/200
# 62/62 [==============================] - 0s 853us/step - loss: 0.0867 - accuracy: 0.9658
# Epoch 97/200
# 62/62 [==============================] - 0s 852us/step - loss: 0.0688 - accuracy: 0.9756
# Epoch 98/200
# 62/62 [==============================] - 0s 771us/step - loss: 0.0703 - accuracy: 0.9772
# Epoch 99/200
# 62/62 [==============================] - 0s 726us/step - loss: 0.0646 - accuracy: 0.9707
# Epoch 100/200
# 62/62 [==============================] - 0s 986us/step - loss: 0.0638 - accuracy: 0.9805
# Epoch 101/200
# 62/62 [==============================] - 0s 898us/step - loss: 0.0635 - accuracy: 0.9788
# Epoch 102/200
# 62/62 [==============================] - 0s 992us/step - loss: 0.0588 - accuracy: 0.9805
# Epoch 103/200
# 62/62 [==============================] - 0s 996us/step - loss: 0.0719 - accuracy: 0.9674
# Epoch 104/200
# 62/62 [==============================] - 0s 961us/step - loss: 0.0802 - accuracy: 0.9674
# Epoch 105/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 0.9788
# Epoch 106/200
# 62/62 [==============================] - 0s 898us/step - loss: 0.0571 - accuracy: 0.9821
# Epoch 107/200
# 62/62 [==============================] - 0s 770us/step - loss: 0.0580 - accuracy: 0.9805
# Epoch 108/200
# 62/62 [==============================] - 0s 773us/step - loss: 0.0594 - accuracy: 0.9821
# Epoch 109/200
# 62/62 [==============================] - 0s 712us/step - loss: 0.0578 - accuracy: 0.9805
# Epoch 110/200
# 62/62 [==============================] - 0s 643us/step - loss: 0.0549 - accuracy: 0.9821
# Epoch 111/200
# 62/62 [==============================] - 0s 579us/step - loss: 0.0537 - accuracy: 0.9821
# Epoch 112/200
# 62/62 [==============================] - 0s 595us/step - loss: 0.0525 - accuracy: 0.9837
# Epoch 113/200
# 62/62 [==============================] - 0s 627us/step - loss: 0.0529 - accuracy: 0.9886
# Epoch 114/200
# 62/62 [==============================] - 0s 786us/step - loss: 0.0452 - accuracy: 0.9870
# Epoch 115/200
# 62/62 [==============================] - 0s 737us/step - loss: 0.0606 - accuracy: 0.9805
# Epoch 116/200
# 62/62 [==============================] - 0s 690us/step - loss: 0.0566 - accuracy: 0.9772
# Epoch 117/200
# 62/62 [==============================] - 0s 641us/step - loss: 0.0586 - accuracy: 0.9837
# Epoch 118/200
# 62/62 [==============================] - 0s 638us/step - loss: 0.0474 - accuracy: 0.9853
# Epoch 119/200
# 62/62 [==============================] - 0s 640us/step - loss: 0.0545 - accuracy: 0.9837
# Epoch 120/200
# 62/62 [==============================] - 0s 643us/step - loss: 0.0461 - accuracy: 0.9837
# Epoch 121/200
# 62/62 [==============================] - 0s 662us/step - loss: 0.0460 - accuracy: 0.9837
# Epoch 122/200
# 62/62 [==============================] - 0s 665us/step - loss: 0.0488 - accuracy: 0.9805
# Epoch 123/200
# 62/62 [==============================] - 0s 644us/step - loss: 0.0456 - accuracy: 0.9805
# Epoch 124/200
# 62/62 [==============================] - 0s 609us/step - loss: 0.0426 - accuracy: 0.9853
# Epoch 125/200
# 62/62 [==============================] - 0s 674us/step - loss: 0.0443 - accuracy: 0.9853
# Epoch 126/200
# 62/62 [==============================] - 0s 633us/step - loss: 0.0379 - accuracy: 0.9902
# Epoch 127/200
# 62/62 [==============================] - 0s 651us/step - loss: 0.0476 - accuracy: 0.9772
# Epoch 128/200
# 62/62 [==============================] - 0s 825us/step - loss: 0.0519 - accuracy: 0.9837
# Epoch 129/200
# 62/62 [==============================] - 0s 615us/step - loss: 0.0560 - accuracy: 0.9805
# Epoch 130/200
# 62/62 [==============================] - 0s 643us/step - loss: 0.0643 - accuracy: 0.9756
# Epoch 131/200
# 62/62 [==============================] - 0s 658us/step - loss: 0.0870 - accuracy: 0.9691
# Epoch 132/200
# 62/62 [==============================] - 0s 612us/step - loss: 0.0619 - accuracy: 0.9805
# Epoch 133/200
# 62/62 [==============================] - 0s 634us/step - loss: 0.0552 - accuracy: 0.9837
# Epoch 134/200
# 62/62 [==============================] - 0s 608us/step - loss: 0.0385 - accuracy: 0.9886
# Epoch 135/200
# 62/62 [==============================] - 0s 670us/step - loss: 0.0333 - accuracy: 0.9919
# Epoch 136/200
# 62/62 [==============================] - 0s 618us/step - loss: 0.0426 - accuracy: 0.9837
# Epoch 137/200
# 62/62 [==============================] - 0s 616us/step - loss: 0.0375 - accuracy: 0.9870
# Epoch 138/200
# 62/62 [==============================] - 0s 595us/step - loss: 0.0366 - accuracy: 0.9919
# Epoch 139/200
# 62/62 [==============================] - 0s 698us/step - loss: 0.0355 - accuracy: 0.9902
# Epoch 140/200
# 62/62 [==============================] - 0s 653us/step - loss: 0.0288 - accuracy: 0.9935
# Epoch 141/200
# 62/62 [==============================] - 0s 775us/step - loss: 0.0304 - accuracy: 0.9919
# Epoch 142/200
# 62/62 [==============================] - 0s 965us/step - loss: 0.0295 - accuracy: 0.9935
# Epoch 143/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9935
# Epoch 144/200
# 62/62 [==============================] - 0s 893us/step - loss: 0.0332 - accuracy: 0.9919
# Epoch 145/200
# 62/62 [==============================] - 0s 805us/step - loss: 0.0336 - accuracy: 0.9886
# Epoch 146/200
# 62/62 [==============================] - 0s 746us/step - loss: 0.0312 - accuracy: 0.9919
# Epoch 147/200
# 62/62 [==============================] - 0s 732us/step - loss: 0.0314 - accuracy: 0.9902
# Epoch 148/200
# 62/62 [==============================] - 0s 626us/step - loss: 0.0314 - accuracy: 0.9902
# Epoch 149/200
# 62/62 [==============================] - 0s 646us/step - loss: 0.0379 - accuracy: 0.9853
# Epoch 150/200
# 62/62 [==============================] - 0s 632us/step - loss: 0.0489 - accuracy: 0.9837
# Epoch 151/200
# 62/62 [==============================] - 0s 687us/step - loss: 0.0690 - accuracy: 0.9756
# Epoch 152/200
# 62/62 [==============================] - 0s 668us/step - loss: 0.0414 - accuracy: 0.9870
# Epoch 153/200
# 62/62 [==============================] - 0s 728us/step - loss: 0.0423 - accuracy: 0.9853
# Epoch 154/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9902
# Epoch 155/200
# 62/62 [==============================] - 0s 901us/step - loss: 0.0224 - accuracy: 0.9951
# Epoch 156/200
# 62/62 [==============================] - 0s 752us/step - loss: 0.0306 - accuracy: 0.9919
# Epoch 157/200
# 62/62 [==============================] - 0s 728us/step - loss: 0.0287 - accuracy: 0.9919
# Epoch 158/200
# 62/62 [==============================] - 0s 706us/step - loss: 0.0276 - accuracy: 0.9935
# Epoch 159/200
# 62/62 [==============================] - 0s 733us/step - loss: 0.0316 - accuracy: 0.9919
# Epoch 160/200
# 62/62 [==============================] - 0s 611us/step - loss: 0.0245 - accuracy: 0.9951
# Epoch 161/200
# 62/62 [==============================] - 0s 644us/step - loss: 0.0256 - accuracy: 0.9935
# Epoch 162/200
# 62/62 [==============================] - 0s 613us/step - loss: 0.0252 - accuracy: 0.9919
# Epoch 163/200
# 62/62 [==============================] - 0s 601us/step - loss: 0.0269 - accuracy: 0.9919
# Epoch 164/200
# 62/62 [==============================] - 0s 663us/step - loss: 0.0253 - accuracy: 0.9935
# Epoch 165/200
# 62/62 [==============================] - 0s 671us/step - loss: 0.0223 - accuracy: 0.9919
# Epoch 166/200
# 62/62 [==============================] - 0s 668us/step - loss: 0.0222 - accuracy: 0.9951
# Epoch 167/200
# 62/62 [==============================] - 0s 638us/step - loss: 0.0234 - accuracy: 0.9919
# Epoch 168/200
# 62/62 [==============================] - 0s 655us/step - loss: 0.0537 - accuracy: 0.9821
# Epoch 169/200
# 62/62 [==============================] - 0s 629us/step - loss: 0.0405 - accuracy: 0.9853
# Epoch 170/200
# 62/62 [==============================] - 0s 679us/step - loss: 0.0407 - accuracy: 0.9821
# Epoch 171/200
# 62/62 [==============================] - 0s 887us/step - loss: 0.0362 - accuracy: 0.9902
# Epoch 172/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9886
# Epoch 173/200
# 62/62 [==============================] - 0s 806us/step - loss: 0.0220 - accuracy: 0.9951
# Epoch 174/200
# 62/62 [==============================] - 0s 797us/step - loss: 0.0417 - accuracy: 0.9886
# Epoch 175/200
# 62/62 [==============================] - 0s 757us/step - loss: 0.0239 - accuracy: 0.9935
# Epoch 176/200
# 62/62 [==============================] - 0s 768us/step - loss: 0.0211 - accuracy: 0.9935
# Epoch 177/200
# 62/62 [==============================] - 0s 637us/step - loss: 0.0166 - accuracy: 0.9935
# Epoch 178/200
# 62/62 [==============================] - 0s 649us/step - loss: 0.0188 - accuracy: 0.9886
# Epoch 179/200
# 62/62 [==============================] - 0s 653us/step - loss: 0.0246 - accuracy: 0.9951
# Epoch 180/200
# 62/62 [==============================] - 0s 696us/step - loss: 0.0177 - accuracy: 0.9935
# Epoch 181/200
# 62/62 [==============================] - 0s 744us/step - loss: 0.0155 - accuracy: 0.9967
# Epoch 182/200
# 62/62 [==============================] - 0s 629us/step - loss: 0.0239 - accuracy: 0.9902
# Epoch 183/200
# 62/62 [==============================] - 0s 621us/step - loss: 0.0158 - accuracy: 0.9967
# Epoch 184/200
# 62/62 [==============================] - 0s 736us/step - loss: 0.0151 - accuracy: 0.9951
# Epoch 185/200
# 62/62 [==============================] - 0s 704us/step - loss: 0.0260 - accuracy: 0.9919
# Epoch 186/200
# 62/62 [==============================] - 0s 619us/step - loss: 0.0145 - accuracy: 0.9951
# Epoch 187/200
# 62/62 [==============================] - 0s 729us/step - loss: 0.0460 - accuracy: 0.9853
# Epoch 188/200
# 62/62 [==============================] - 0s 707us/step - loss: 0.0399 - accuracy: 0.9886
# Epoch 189/200
# 62/62 [==============================] - 0s 950us/step - loss: 0.0457 - accuracy: 0.9739
# Epoch 190/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9886
# Epoch 191/200
# 62/62 [==============================] - 0s 931us/step - loss: 0.0249 - accuracy: 0.9919
# Epoch 192/200
# 62/62 [==============================] - 0s 981us/step - loss: 0.0126 - accuracy: 0.9984
# Epoch 193/200
# 62/62 [==============================] - 0s 997us/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 194/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.9967
# Epoch 195/200
# 62/62 [==============================] - 0s 946us/step - loss: 0.0125 - accuracy: 0.9951
# Epoch 196/200
# 62/62 [==============================] - 0s 993us/step - loss: 0.0162 - accuracy: 0.9951
# Epoch 197/200
# 62/62 [==============================] - 0s 949us/step - loss: 0.0143 - accuracy: 0.9951
# Epoch 198/200
# 62/62 [==============================] - 0s 981us/step - loss: 0.0107 - accuracy: 0.9967
# Epoch 199/200
# 62/62 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9984
# Epoch 200/200
# 62/62 [==============================] - 0s 996us/step - loss: 0.0205 - accuracy: 0.9951
# 5/5 [==============================] - 0s 781us/step - loss: 1.7495 - accuracy: 0.8312

# %%
print('Accuracy of Neural network: %.2f' % (nn_acc*100))
print('Accuracy of logistic regression : %.2f' % (log_score.mean()*100))
print('Accuracy of Knn: %.2f' % (knn_score.mean()*100))
print('Accuracy of Random Forest Classifier : %.2f' % (clfm_score.mean()*100))
print('Accuracy of SVM : %.2f' % (svm_score.mean()*100))
