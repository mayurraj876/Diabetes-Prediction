# %%
import numpy as np   
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#models
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from keras.models import Sequential
from keras.layers import Dense
#Evaluation
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix, classification_report,plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# # Data processing

# %%
data = pd.read_csv("diabetes.csv")
attributes = data.drop("Outcome",axis=1).columns

# %%
def violin_plot(nrow=4,ncol=2): 
    """
    funtion to plot violin plot for all attributes
    
    input : optional input for number of column and rows for subplot by default value are 2,4 respectively
    
    output : violin plot for all attribute of dataframe 
    
    return : none
    """
    fig = plt.figure(figsize=(14,25))
    fig.tight_layout(pad=3.0)
    nrow,ncol,index=4,2,1    
    for attribute in attributes:
        plt.subplot(nrow, ncol, index)
        plt.title(attribute)
        sns.violinplot(x="Outcome", y=attribute, data=data)
        index+=1
    plt.show()
        
    
# calculation of median for each attribute for both possible outcome  
def median_target(attribute):
    """
    This function replaces the Nan of given attribute with 
    median when grouped by Outcome into the global variable 
    data("dataframe")
    
    input : attribute 
    
    output : column of that attibute is modified 
    
    return : none
    """
        temp = data[data[attribute].notnull()]# assigning non null value to temp 
        temp = temp[[attribute, 'Outcome']].groupby(['Outcome'])[[attribute]].mean().reset_index() #calculate mean for a attribute with either 0 or 1 outcome 
        mean_op_0=temp[attribute][0]
        mean_op_1=temp[attribute][1]
        data.loc[(data['Outcome'] == 0 ) & (data[attribute].isnull()), attribute] = mean_op_0 #assigning mean to null values 
        data.loc[(data['Outcome'] == 1 ) & (data[attribute].isnull()), attribute] = mean_op_1
    
def outliers_removal():
    """
    This function removes outlier of the global variable data(dataframe)
    using IQR method 
    """
    #loop for replacing outlier of all attribute with Nan value 
    for attribute in attributes:
        q1 = data[attribute].quantile(0.25)
        q3 = data[attribute].quantile(0.75)
        iqr = q3 - q1
        fence_low = q1 - 1.5 * iqr
        fence_high = q3 + 1.5 * iqr
        data.loc[(data[attribute] < fence_low) | (data[attribute] > fence_high),attribute]=np.nan

violin_plot()

# %%
#replacing missing value with nan value
data[["Glucose",  "BloodPressure","SkinThickness","Insulin","BMI"]]=data[["Glucose",  "BloodPressure","SkinThickness","Insulin","BMI"]].replace(0,np.nan)

#calling meadian_target for each attribute
for attribute in attributes:
        median_target(attribute)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB
# None

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))
fig.tight_layout(pad=3.0)
k=0
for i in range(0,4):
    for j in range(0,2):
        ax[i,j].set_title(attributes[k])
        ax[i,j].hist(data[attributes[k]][data.Outcome==1],color="green")
        k+=1

# %%
violin_plot()

# %%
# standardization of dataset
def z_score(df):
    """Function for apply z score standardization
       Input: dataframe to be standardized
       output :standardized dataframe 
    """
    df_std = df.copy()
    for column in df_std.columns:
        df_std[column] = (df_std[column] - df_std[column].mean()) / df_std[column].std()     
    return df_std
data_std=z_score(data)

# %%
# It shows the correlation(positive,neagative) between different columns(only integer value columns) 
corr_matrix = data_std.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,annot=True,linewidth=0.5,fmt=".2f",cmap="RdYlBu")

# %% [markdown]
# ###### Distribution of data set

# %%
y = data["Outcome"]
X=data_std.drop("Outcome",axis=1)
X_train,X_test,y_train,y_test =  train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Models

# %%
"""from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
list_of_algo=[SVC(),AdaBoostClassifier(), 
              RandomForestClassifier(),
              LogisticRegression(),KNeighborsClassifier()]
name_of_algo=["SVM","AdaBoostClassifier", 
              "RandomForestClassifier",
              "LogisticRegression","KNeighborsClassifier"]
for i,algorithm in enumerate(list_of_algo):
    steps = [('pca', PCA(n_components=6)), ('m', algorithm)]
    model = Pipeline(steps=steps)
# evaluate model
    model_score = cross_val_score(model, X, y, scoring='accuracy', n_jobs=-1, error_score='raise')
    print("*"*120)
    print('Accuracy of {} : {} '.format(name_of_algo[i],(model_score.mean()*100)))"""
# Out:
# ************************************************************************************************************************
# Accuracy of SVM : 85.16000339529751
# ************************************************************************************************************************
# Accuracy of AdaBoostClassifier : 81.1272387742976
# ************************************************************************************************************************
# Accuracy of RandomForestClassifier : 82.42678889737712
# ************************************************************************************************************************
# Accuracy of LogisticRegression : 79.17154740684154
# ************************************************************************************************************************
# Accuracy of KNeighborsClassifier : 82.94457176810118

# %%
def plot_auc(fpr,tpr,auc):
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='RF (area = {:.3f})'.format(auc))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()

# %%
from sklearn.metrics import roc_curve,auc
list_of_algo=[SVC(),AdaBoostClassifier(), 
              RandomForestClassifier(),
              LogisticRegression(),KNeighborsClassifier()]
name_of_algo=["SVM","AdaBoostClassifier", 
              "RandomForestClassifier",
              "LogisticRegression","KNeighborsClassifier"]
for i,algorithm in enumerate(list_of_algo):
    model=algorithm
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    model_score=cross_val_score(model,X,y,cv=15)
    
    y_pred_prob = model.predict_
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    auc_model = auc(fpr, tpr)
    print("*"*120)
    print('Accuracy of {} : {} '.format(name_of_algo[i],(model_score.mean()*100)))
    print('Precision of {} : {} '.format(name_of_algo[i],(precision_score(y_test,y_pred)*100)))
    print('Recall of {} : {} '.format(name_of_algo[i],(recall_score(y_test,y_pred)*100)))
    plot_auc(fpr,tpr,auc_model)
    plot_confusion_matrix(model, X_test, y_test,values_format="d")
    plt.title(name_of_algo[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-c32edb6c9669> in <module>
#      12     model_score=cross_val_score(model,X,y,cv=15)
#      13
# ---> 14     y_pred_prob = model.predict_proba(X_test)[:, 1]
#      15     fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
#      16     auc_model = auc(fpr, tpr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py in predict_proba(self)
#     634         datasets.
#     635         """
# --> 636         self._check_proba()
#     637         return self._predict_proba
#     638
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py in _check_proba(self)
#     601     def _check_proba(self):
#     602         if not self.probability:
# --> 603             raise AttributeError("predict_proba is not available when "
#     604                                  " probability=False")
#     605         if self._impl not in ('c_svc', 'nu_svc'):
#
# AttributeError: predict_proba is not available when  probability=False

# %%
"""from sklearn.model_selection import GridSearchCV
print(RandomForestClassifier())
n_estimators = [100, 200, 250, 300, 350]
max_depth = [1, 3, 4, 5, 8, 10]
min_samples_split = [10, 15, 20, 25, 30, 100]
min_samples_leaf = [1, 2, 4, 5, 7] 
max_features = ['auto', 'sqrt']
bootstrap = [True, False]
rfr=RandomForestClassifier()
hyperF = dict(n_estimators = n_estimators, max_depth = max_depth,
              max_features = max_features,  min_samples_split = min_samples_split, 
              min_samples_leaf = min_samples_leaf,bootstrap = bootstrap)

gridF = GridSearchCV(rfr, hyperF,scoring='accuracy', cv = 5, verbose = 1, 
                      n_jobs = -1)
bestF = gridF.fit(X_train, y_train)"""
# Out:
# "from sklearn.model_selection import GridSearchCV\nprint(RandomForestClassifier())\nn_estimators = [100, 200, 250, 300, 350]\nmax_depth = [1, 3, 4, 5, 8, 10]\nmin_samples_split = [10, 15, 20, 25, 30, 100]\nmin_samples_leaf = [1, 2, 4, 5, 7] \nmax_features = ['auto', 'sqrt']\nbootstrap = [True, False]\nrfr=RandomForestClassifier()\nhyperF = dict(n_estimators = n_estimators, max_depth = max_depth,\n              max_features = max_features,  min_samples_split = min_samples_split, \n              min_samples_leaf = min_samples_leaf,bootstrap = bootstrap)\n\ngridF = GridSearchCV(rfr, hyperF,scoring='accuracy', cv = 5, verbose = 1, \n                      n_jobs = -1)\nbestF = gridF.fit(X_train, y_train)"

# %%
forestOpt = RandomForestClassifier(n_estimators = 100,criterion='gini')

modelOpt = forestOpt.fit(X_train, y_train)
model_score=cross_val_score(forestOpt,X,y,cv=4)
y_pred = modelOpt.predict(X_test)
print(modelOpt.score(X_test,y_test))
print("score",model_score.mean())
# Out:
# 0.9025974025974026
# score 0.88671875

# %%
##Build an model(Neural model )
model = Sequential()
model.add(Dense(8, input_dim=8, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_fit=model.fit(X_train, y_train, epochs=200, batch_size=4)
_, nn_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/200
# 154/154 [==============================] - 2s 11ms/step - loss: 0.5650 - accuracy: 0.6987
# Epoch 2/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.4542 - accuracy: 0.7948
# Epoch 3/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.4218 - accuracy: 0.8062
# Epoch 4/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.4066 - accuracy: 0.8046
# Epoch 5/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3914 - accuracy: 0.8192
# Epoch 6/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3794 - accuracy: 0.8225
# Epoch 7/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3649 - accuracy: 0.8257
# Epoch 8/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3526 - accuracy: 0.8502
# Epoch 9/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3488 - accuracy: 0.8534
# Epoch 10/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8518
# Epoch 11/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.8648
# Epoch 12/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.8632
# Epoch 13/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3084 - accuracy: 0.8632
# Epoch 14/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8713
# Epoch 15/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2999 - accuracy: 0.8762
# Epoch 16/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.8860
# Epoch 17/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2804 - accuracy: 0.8893
# Epoch 18/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.8925
# Epoch 19/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8941
# Epoch 20/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.8990
# Epoch 21/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.9055
# Epoch 22/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2401 - accuracy: 0.9039
# Epoch 23/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2363 - accuracy: 0.9039
# Epoch 24/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9153
# Epoch 25/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.9153
# Epoch 26/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.9072
# Epoch 27/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.2062 - accuracy: 0.9169
# Epoch 28/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9153
# Epoch 29/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9202
# Epoch 30/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.9202
# Epoch 31/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1899 - accuracy: 0.9218
# Epoch 32/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9300
# Epoch 33/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9251
# Epoch 34/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.9283
# Epoch 35/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1690 - accuracy: 0.9365
# Epoch 36/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9332
# Epoch 37/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1621 - accuracy: 0.9349
# Epoch 38/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1624 - accuracy: 0.9365
# Epoch 39/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.1548 - accuracy: 0.9349
# Epoch 40/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.1560 - accuracy: 0.9414
# Epoch 41/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.9430
# Epoch 42/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1484 - accuracy: 0.9528
# Epoch 43/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9414
# Epoch 44/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.9397
# Epoch 45/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1396 - accuracy: 0.9479
# Epoch 46/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.9479
# Epoch 47/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 0.9528
# Epoch 48/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9593
# Epoch 49/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1290 - accuracy: 0.9414
# Epoch 50/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9593
# Epoch 51/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9593
# Epoch 52/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9658
# Epoch 53/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.9642
# Epoch 54/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9593
# Epoch 55/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9577
# Epoch 56/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.9642
# Epoch 57/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9642
# Epoch 58/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9723
# Epoch 59/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9723
# Epoch 60/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9625
# Epoch 61/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0958 - accuracy: 0.9674
# Epoch 62/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9772
# Epoch 63/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 0.9642
# Epoch 64/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1008 - accuracy: 0.9593
# Epoch 65/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.9511
# Epoch 66/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0809 - accuracy: 0.9707
# Epoch 67/200
# 154/154 [==============================] - 0s 931us/step - loss: 0.0799 - accuracy: 0.9674
# Epoch 68/200
# 154/154 [==============================] - 0s 952us/step - loss: 0.0741 - accuracy: 0.9723
# Epoch 69/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 0.9723
# Epoch 70/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9707
# Epoch 71/200
# 154/154 [==============================] - 0s 917us/step - loss: 0.0791 - accuracy: 0.9658
# Epoch 72/200
# 154/154 [==============================] - 0s 946us/step - loss: 0.0773 - accuracy: 0.9723
# Epoch 73/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9772
# Epoch 74/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9739
# Epoch 75/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0643 - accuracy: 0.9707
# Epoch 76/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0690 - accuracy: 0.9691
# Epoch 77/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9593
# Epoch 78/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.9674
# Epoch 79/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9691
# Epoch 80/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0749 - accuracy: 0.9723
# Epoch 81/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9805
# Epoch 82/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9739
# Epoch 83/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9739
# Epoch 84/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9707
# Epoch 85/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 0.9805
# Epoch 86/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9805
# Epoch 87/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0443 - accuracy: 0.9821
# Epoch 88/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9788
# Epoch 89/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9805
# Epoch 90/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9658
# Epoch 91/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9707
# Epoch 92/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9837
# Epoch 93/200
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0418 - accuracy: 0.9837
# Epoch 94/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 0.9853
# Epoch 95/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 0.9788
# Epoch 96/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9870
# Epoch 97/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9853
# Epoch 98/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9870
# Epoch 99/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9772
# Epoch 100/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9739
# Epoch 101/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9788
# Epoch 102/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9723
# Epoch 103/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9853
# Epoch 104/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0295 - accuracy: 0.9870: 0s - loss: 0.0466
# Epoch 105/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9886
# Epoch 106/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9805
# Epoch 107/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 0.9821
# Epoch 108/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9756
# Epoch 109/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9853
# Epoch 110/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9756
# Epoch 111/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9853
# Epoch 112/200
# 154/154 [==============================] - 0s 848us/step - loss: 0.0227 - accuracy: 0.9935
# Epoch 113/200
# 154/154 [==============================] - 0s 848us/step - loss: 0.0231 - accuracy: 0.9935
# Epoch 114/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 0.9919
# Epoch 115/200
# 154/154 [==============================] - 0s 907us/step - loss: 0.0196 - accuracy: 0.9919
# Epoch 116/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9919
# Epoch 117/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9919
# Epoch 118/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9919
# Epoch 119/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9837
# Epoch 120/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.9463
# Epoch 121/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9772
# Epoch 122/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9902
# Epoch 123/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9886
# Epoch 124/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9902
# Epoch 125/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 0.9902
# Epoch 126/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9935
# Epoch 127/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9935
# Epoch 128/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9951
# Epoch 129/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9902
# Epoch 130/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9935
# Epoch 131/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.9935
# Epoch 132/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9935
# Epoch 133/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0626 - accuracy: 0.9707
# Epoch 134/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1100 - accuracy: 0.9642
# Epoch 135/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.9805
# Epoch 136/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9951
# Epoch 137/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9919
# Epoch 138/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9951
# Epoch 139/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9967
# Epoch 140/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9967
# Epoch 141/200
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0159 - accuracy: 0.9935
# Epoch 142/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9951
# Epoch 143/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.9967
# Epoch 144/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9984
# Epoch 145/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9967
# Epoch 146/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9951
# Epoch 147/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9935
# Epoch 148/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 149/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9967
# Epoch 150/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9919
# Epoch 151/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9658
# Epoch 152/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9756
# Epoch 153/200
# 154/154 [==============================] - 0s 939us/step - loss: 0.0618 - accuracy: 0.9739
# Epoch 154/200
# 154/154 [==============================] - 0s 879us/step - loss: 0.0192 - accuracy: 0.9951
# Epoch 155/200
# 154/154 [==============================] - 0s 902us/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 156/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 157/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9984
# Epoch 158/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 159/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 160/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 161/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 162/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9984
# Epoch 163/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9967
# Epoch 164/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9984
# Epoch 165/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9821
# Epoch 166/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9723
# Epoch 167/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9902
# Epoch 168/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9919
# Epoch 169/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9902
# Epoch 170/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9886
# Epoch 171/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 172/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.9967
# Epoch 173/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 174/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9984
# Epoch 175/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 176/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 177/200
# 154/154 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 178/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9984
# Epoch 179/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9951
# Epoch 180/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 0.9967
# Epoch 181/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9870
# Epoch 182/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.1722 - accuracy: 0.9625
# Epoch 183/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.9805
# Epoch 184/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9902
# Epoch 185/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 186/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 187/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 188/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 189/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 190/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 191/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 192/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 193/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 194/200
# 154/154 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 195/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9756
# Epoch 196/200
# 154/154 [==============================] - 0s 900us/step - loss: 0.0973 - accuracy: 0.9691
# Epoch 197/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0421 - accuracy: 0.9821
# Epoch 198/200
# 154/154 [==============================] - 0s 971us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 199/200
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 200/200
# 154/154 [==============================] - 0s 907us/step - loss: 0.0050 - accuracy: 1.0000
# 5/5 [==============================] - 0s 2ms/step - loss: 2.1104 - accuracy: 0.8442
